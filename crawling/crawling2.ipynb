# %%
pip list
# Out:
# Package                       Version
# ----------------------------- --------------------
# alabaster                     0.7.12
# anaconda-client               1.11.0
# anaconda-navigator            2.3.1
# anaconda-project              0.11.1
# anyio                         3.5.0
# appdirs                       1.4.4
# argon2-cffi                   21.3.0
# argon2-cffi-bindings          21.2.0
# arrow                         1.2.2
# astroid                       2.11.7
# astropy                       5.1
# atomicwrites                  1.4.0
# attrs                         21.4.0
# Automat                       20.2.0
# autopep8                      1.6.0
# Babel                         2.9.1
# backcall                      0.2.0
# backports.functools-lru-cache 1.6.4
# backports.tempfile            1.0
# backports.weakref             1.0.post1
# bcrypt                        3.2.0
# beautifulsoup4                4.11.1
# binaryornot                   0.4.4
# ...

# %%
import requests
import bs4
import re
from bs4 import BeautifulSoup
from urllib.request import urlopen

# %%
html = """
<html>
    <body>
        <h1 id='title'>[1]크롤링이란?</h1>;
        <p class='cssstyle'>웹페이지에서 필요한 데이터를 추출하는 것</p>
        <p class='cssstyle2'>html과 xml 파싱가능</p>
        <p id='body' align='center'>파이썬을 중심으로 다양한 웹크롤링 기술 발달</p>
    </body>
</html>
"""

# %%
html
# Out:
# "\n<html>\n    <body>\n        <h1 id='title'>[1]크롤링이란?</h1>;\n        <p class='cssstyle'>웹페이지에서 필요한 데이터를 추출하는 것</p>\n        <p class='cssstyle2'>html과 xml 파싱가능</p>\n        <p id='body' align='center'>파이썬을 중심으로 다양한 웹크롤링 기술 발달</p>\n    </body>\n</html>\n"

# %%
soup = BeautifulSoup(html, "html.parser")
soup
# Out:
# <html>
# <body>
# <h1 id="title">[1]크롤링이란?</h1>;
#         <p class="cssstyle">웹페이지에서 필요한 데이터를 추출하는 것</p>
# <p class="cssstyle2">html과 xml 파싱가능</p>
# <p align="center" id="body">파이썬을 중심으로 다양한 웹크롤링 기술 발달</p>
# </body>
# </html>

# %%
soup.find("p")
# Out:
# <p class="cssstyle">웹페이지에서 필요한 데이터를 추출하는 것</p>

# %%
soup.find("span")

# %%
soup.find("body")
# Out:
# <body>
# <h1 id="title">[1]크롤링이란?</h1>;
#         <p class="cssstyle">웹페이지에서 필요한 데이터를 추출하는 것</p>
# <p class="cssstyle2">html과 xml 파싱가능</p>
# <p align="center" id="body">파이썬을 중심으로 다양한 웹크롤링 기술 발달</p>
# </body>

# %%
soup.find("h1")
# Out:
# <h1 id="title">[1]크롤링이란?</h1>

# %%
soup.find("p")
# Out:
# <p class="cssstyle">웹페이지에서 필요한 데이터를 추출하는 것</p>

# %%
soup.find_all("p")   # ---------- list로 나온다
# Out:
# [<p class="cssstyle">웹페이지에서 필요한 데이터를 추출하는 것</p>,
#  <p class="cssstyle2">html과 xml 파싱가능</p>,
#  <p align="center" id="body">파이썬을 중심으로 다양한 웹크롤링 기술 발달</p>]

# %%
soup.find_all("p")[0]
# Out:
# <p class="cssstyle">웹페이지에서 필요한 데이터를 추출하는 것</p>

# %%
soup.find_all("p")[0].get_text()
# Out:
# '웹페이지에서 필요한 데이터를 추출하는 것'

# %%
soup.find_all("p")[0].string
# Out:
# '웹페이지에서 필요한 데이터를 추출하는 것'

# %%
for i in range(0,3):
    print(soup.find_all("p")[i].get_text())
# Out:
# 웹페이지에서 필요한 데이터를 추출하는 것
# html과 xml 파싱가능
# 파이썬을 중심으로 다양한 웹크롤링 기술 발달

# %% [markdown]
# * url open

# %%
html=urlopen("http://www.naver.com")

# %%
html

# %%
bsObject=BeautifulSoup(html, "html.parser")
bsObject
# Out:
# <!DOCTYPE html>
# ...

# %%
bsObject.head.find_all('meta')
# Out:
# [<meta charset="utf-8"/>,
#  <meta content="IE=edge" http-equiv="X-UA-Compatible"/>,
#  <meta content="width=1190" name="viewport"/>,
# ...

# %%
bsObject.head.find('meta', {'name':'description'}).get('content')
# Out:
# '네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요'

# %%
bsObject.select('link')
# Out:
# [<link href="https://pm.pstatic.net/dist/css/nmain.20221110.css" rel="stylesheet"/>,
#  <link href="https://ssl.pstatic.net/sstatic/search/pc/css/sp_autocomplete_220526.css" rel="stylesheet"/>,
# ...

# %%
bsObject.select('a')
# Out:
# [<a href="#newsstand"><span>뉴스스탠드 바로가기</span></a>,
#  <a href="#themecast"><span>주제별캐스트 바로가기</span></a>,
#  <a href="#timesquare"><span>타임스퀘어 바로가기</span></a>,
#  <a href="#shopcast"><span>쇼핑캐스트 바로가기</span></a>,
#  <a href="#account"><span>로그인 바로가기</span></a>,
#  <a class="_3h-N8T9V" data-clk="dropbanner1b" href="https://whale.naver.com/ko/details/security/&amp;wpid=RydDy7"></a>,
#  <a class="_2aeXMlrb BMgpjddw" data-clk="dropdownload1b" href="https://installer-whale.pstatic.net/downloads/banner/RydDy7/WhaleSetup.exe" id="NM_whale_download_btn"><span style="background-color: #0436c7">다운로드</span></a>,
#  <a class="logo_naver" data-clk="top.logo" href="/"><span class="blind">네이버</span></a>,
#  <a class="link_set" data-clk="top.mkhome" href="https://help.naver.com/support/welcomePage/guide.help" id="NM_set_home_btn">네이버를 시작페이지로</a>,
#  <a class="link_jrnaver" data-clk="top.jrnaver" href="https://jr.naver.com"><i class="ico_jrnaver"></i><span class="blind">쥬니어네이버</span></a>,
# ...

# %%
bsObject.select('a[href]')
# Out:
# [<a href="#newsstand"><span>뉴스스탠드 바로가기</span></a>,
#  <a href="#themecast"><span>주제별캐스트 바로가기</span></a>,
#  <a href="#timesquare"><span>타임스퀘어 바로가기</span></a>,
#  <a href="#shopcast"><span>쇼핑캐스트 바로가기</span></a>,
#  <a href="#account"><span>로그인 바로가기</span></a>,
#  <a class="_3h-N8T9V" data-clk="dropbanner1b" href="https://whale.naver.com/ko/details/security/&amp;wpid=RydDy7"></a>,
#  <a class="_2aeXMlrb BMgpjddw" data-clk="dropdownload1b" href="https://installer-whale.pstatic.net/downloads/banner/RydDy7/WhaleSetup.exe" id="NM_whale_download_btn"><span style="background-color: #0436c7">다운로드</span></a>,
#  <a class="logo_naver" data-clk="top.logo" href="/"><span class="blind">네이버</span></a>,
#  <a class="link_set" data-clk="top.mkhome" href="https://help.naver.com/support/welcomePage/guide.help" id="NM_set_home_btn">네이버를 시작페이지로</a>,
#  <a class="link_jrnaver" data-clk="top.jrnaver" href="https://jr.naver.com"><i class="ico_jrnaver"></i><span class="blind">쥬니어네이버</span></a>,
# ...

# %%
links = bsObject.select('a[href]')

# %%
for link in links:
    if re.search('http://\w+', link['href']):
        print(link['href'])
# Out:
# http://news.naver.com/
# http://entertain.naver.com/home
# http://sports.news.naver.com/
# http://news.naver.com/main/main.naver?mode=LSD&mid=shm&sid1=101
# http://newsstand.naver.com/
# http://newsstand.naver.com/config.html
# http://newsstand.naver.com/?list=&pcode=002
# http://newsstand.naver.com/?list=&pcode=044
# http://newsstand.naver.com/?list=&pcode=028
# http://newsstand.naver.com/?list=&pcode=011
# http://newsstand.naver.com/?list=&pcode=092
# http://newsstand.naver.com/?list=&pcode=008
# http://newsstand.naver.com/?list=&pcode=015
# http://newsstand.naver.com/?list=&pcode=005
# http://newsstand.naver.com/?list=&pcode=009
# http://newsstand.naver.com/?list=&pcode=327
# http://newsstand.naver.com/?list=&pcode=057
# http://newsstand.naver.com/?list=&pcode=214
# http://newsstand.naver.com/?list=&pcode=241
# http://newsstand.naver.com/?list=&pcode=018
# http://newsstand.naver.com/?list=&pcode=330
# http://newsstand.naver.com/?list=&pcode=140
# ...

# %%
bsObject.select('div[class="group_weather"]')
# Out:
# [<div class="group_weather" id="NM_WEATHER">
#  <div>
#  <a class="weather_area ico_w07" data-clk="squ.weat" href="https://weather.naver.com/today/09590107?cpName=KMA">
#  <div class="current_box">
#  <strong aria-label="현재기온" class="current">7.2°</strong><strong class="state">흐림</strong>
#  </div>
#  <div class="degree_box">
#  <span aria-label="최저기온" class="min">2.0°</span><span aria-label="최고기온" class="max">9.0°</span>
#  </div>
#  <span class="location">사당동</span>
#  </a>
#  </div>
#  <div>
#  <a class="air_area" data-clk="squ.dust" href="https://weather.naver.com/today/09590107?cpName=KMA">
#  <ul class="list_air">
#  <li class="air_item">미세<strong class="state state_good">좋음</strong></li>
#  <li class="air_item">초미세<strong class="state state_normal">보통</strong></li>
#  </ul>
#  <span class="location">사당동</span>
#  </a>
#  </div>
#  </div>]

# %%
group_weather=bsObject.select('div[class="group_weather"]')

# %%
for i in bsObject.find_all('a[href]'):
    print(i)

# %%
for i in bsObject.find_all('a'):
    print(i)
# Out:
# <a href="#newsstand"><span>뉴스스탠드 바로가기</span></a>
# <a href="#themecast"><span>주제별캐스트 바로가기</span></a>
# <a href="#timesquare"><span>타임스퀘어 바로가기</span></a>
# <a href="#shopcast"><span>쇼핑캐스트 바로가기</span></a>
# <a href="#account"><span>로그인 바로가기</span></a>
# <a class="_3h-N8T9V" data-clk="dropbanner1b" href="https://whale.naver.com/ko/details/security/&amp;wpid=RydDy7"></a>
# <a class="_2aeXMlrb BMgpjddw" data-clk="dropdownload1b" href="https://installer-whale.pstatic.net/downloads/banner/RydDy7/WhaleSetup.exe" id="NM_whale_download_btn"><span style="background-color: #0436c7">다운로드</span></a>
# <a class="logo_naver" data-clk="top.logo" href="/"><span class="blind">네이버</span></a>
# <a class="link_set" data-clk="top.mkhome" href="https://help.naver.com/support/welcomePage/guide.help" id="NM_set_home_btn">네이버를 시작페이지로</a>
# <a class="link_jrnaver" data-clk="top.jrnaver" href="https://jr.naver.com"><i class="ico_jrnaver"></i><span class="blind">쥬니어네이버</span></a>
# ...

# %%
list = bsObject.find_all('a')
for i in list:
    print(i.text.strip(), i.get('href'))
# Out:
# 뉴스스탠드 바로가기 #newsstand
# 주제별캐스트 바로가기 #themecast
# 타임스퀘어 바로가기 #timesquare
# 쇼핑캐스트 바로가기 #shopcast
# 로그인 바로가기 #account
#  https://whale.naver.com/ko/details/security/&wpid=RydDy7
# 다운로드 https://installer-whale.pstatic.net/downloads/banner/RydDy7/WhaleSetup.exe
# 네이버 /
# 네이버를 시작페이지로 https://help.naver.com/support/welcomePage/guide.help
# 쥬니어네이버 https://jr.naver.com
# 해피빈 https://happybean.naver.com
# 한글 입력기 #
# 자동완성 레이어 #
# 전체삭제 #
# @txt@ #
# 삭제 #
# 도움말 https://help.naver.com/support/alias/search/word/word_29.naver
# 도움말 https://help.naver.com/support/alias/search/word/word_29.naver
# 도움말 https://help.naver.com/support/service/main.help?serviceNo=605&categoryNo=1991
# 자동저장 끄기 #
# @5@회차 당첨번호
#
# 추첨 @13@.지급기한 1년
#
#
#
#
# @6@@7@@8@@9@@10@@11@@12@ #
# @14@
#
# @txt@@currency@
#
# @8@(@9@%)
#
#
#
# @6@원 #
# @txt@
#
# @7@, @message@
#
#
#
#
#
# @7@
# @8@° #
# @txt@
#
# @5@
#
#
#
# 바로가기 @5@
# @txt@ #
# 추가 #
# @txt@ #
# 추가 #
# @query@ @intend@ #
# 추가 #
# 자세히보기 #
# ...

# %%
res=requests.get('https://www.google.com/')
print(res)
# Out:
# <Response [200]>

# %%
print(res.content)
# Out:
# b'<!doctype html><html itemscope="" itemtype="http://schema.org/WebPage" lang="ko"><head><meta content="text/html; charset=UTF-8" http-equiv="Content-Type"><meta content="/images/branding/googleg/1x/googleg_standard_color_128dp.png" itemprop="image"><title>Google</title><script nonce="NlIXWvm0jfBZv-n9AHdPKw">(function(){window.google={kEI:\'NqHpY_W_Ad7U2roPp_SSgAY\',kEXPI:\'0,18168,1341241,1710,4349,206,2414,2390,2316,383,246,5,1129120,1197775,380716,16111,28687,22430,1362,284,12031,17584,4998,13228,3847,10623,27821,1593,1279,2891,1103,3037,4108,3506,606,18990,10853,24300,3042,1654,1851,15756,3,346,230,6460,148,13975,4,1528,2304,42127,13658,4437,9358,7428,5830,2527,4094,7596,1,42154,2,14022,7646,18093,5679,1020,14866,16257,4567,6253,23424,1252,5835,14967,4333,19,7465,445,2,2,1,10957,15675,8155,7381,15969,874,6577,13056,7,1922,5784,3996,8212,4202,8975,389,14375,6305,2007,18192,20136,14,82,890,3751,15565,1622,1779,4976,10239,4652,1742,4632,1542,568,988,3030,426,5685,1410,20,3,867,136,2
# ...

# %%
soup=BeautifulSoup(res.content,'html.parser')
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
slist=soup.select('a[href]')
slist
# Out:
# [<a class="gb1" href="https://www.google.co.kr/imghp?hl=ko&amp;tab=wi">이미지</a>,
#  <a class="gb1" href="https://maps.google.co.kr/maps?hl=ko&amp;tab=wl">지도</a>,
#  <a class="gb1" href="https://play.google.com/?hl=ko&amp;tab=w8">Play</a>,
#  <a class="gb1" href="https://www.youtube.com/?tab=w1">YouTube</a>,
#  <a class="gb1" href="https://news.google.com/?tab=wn">뉴스</a>,
#  <a class="gb1" href="https://mail.google.com/mail/?tab=wm">Gmail</a>,
#  <a class="gb1" href="https://drive.google.com/?tab=wo">드라이브</a>,
#  <a class="gb1" href="https://www.google.co.kr/intl/ko/about/products?tab=wh" style="text-decoration:none"><u>더보기</u> »</a>,
#  <a class="gb4" href="http://www.google.co.kr/history/optout?hl=ko">웹 기록</a>,
#  <a class="gb4" href="/preferences?hl=ko">설정</a>,
#  <a class="gb4" href="https://accounts.google.com/ServiceLogin?hl=ko&amp;passive=true&amp;continue=https://www.google.com/&amp;ec=GAZAAQ" id="gb_70" target="_top">로그인</a>,
# ...

# %%
for s in slist:
    if re.search('http://\w+', s['href']):
        print(s)
# Out:
# <a class="gb4" href="http://www.google.co.kr/history/optout?hl=ko">웹 기록</a>
# <a href="http://www.google.co.kr/intl/ko/services/">비즈니스 솔루션</a>

# %%
for s in slist:
    if re.search('https://\w+', s['href']):
        print(s)
# Out:
# <a class="gb1" href="https://www.google.co.kr/imghp?hl=ko&amp;tab=wi">이미지</a>
# <a class="gb1" href="https://maps.google.co.kr/maps?hl=ko&amp;tab=wl">지도</a>
# <a class="gb1" href="https://play.google.com/?hl=ko&amp;tab=w8">Play</a>
# <a class="gb1" href="https://www.youtube.com/?tab=w1">YouTube</a>
# <a class="gb1" href="https://news.google.com/?tab=wn">뉴스</a>
# <a class="gb1" href="https://mail.google.com/mail/?tab=wm">Gmail</a>
# <a class="gb1" href="https://drive.google.com/?tab=wo">드라이브</a>
# <a class="gb1" href="https://www.google.co.kr/intl/ko/about/products?tab=wh" style="text-decoration:none"><u>더보기</u> »</a>
# <a class="gb4" href="https://accounts.google.com/ServiceLogin?hl=ko&amp;passive=true&amp;continue=https://www.google.com/&amp;ec=GAZAAQ" id="gb_70" target="_top">로그인</a>
# <a href="https://www.google.com/setprefdomain?prefdom=KR&amp;prev=https://www.google.co.kr/&amp;sig=K_iqWKtOFT9I-VnaUzwteqm-IYzRY%3D">Google.co.kr</a>

# %%
for s in slist:
    if re.search('http://\w+', s['href']):
        print(s['href'])
# Out:
# http://www.google.co.kr/history/optout?hl=ko
# http://www.google.co.kr/intl/ko/services/

# %%
slist
# Out:
# [<a class="gb1" href="https://www.google.co.kr/imghp?hl=ko&amp;tab=wi">이미지</a>,
#  <a class="gb1" href="https://maps.google.co.kr/maps?hl=ko&amp;tab=wl">지도</a>,
#  <a class="gb1" href="https://play.google.com/?hl=ko&amp;tab=w8">Play</a>,
#  <a class="gb1" href="https://www.youtube.com/?tab=w1">YouTube</a>,
#  <a class="gb1" href="https://news.google.com/?tab=wn">뉴스</a>,
#  <a class="gb1" href="https://mail.google.com/mail/?tab=wm">Gmail</a>,
#  <a class="gb1" href="https://drive.google.com/?tab=wo">드라이브</a>,
#  <a class="gb1" href="https://www.google.co.kr/intl/ko/about/products?tab=wh" style="text-decoration:none"><u>더보기</u> »</a>,
#  <a class="gb4" href="http://www.google.co.kr/history/optout?hl=ko">웹 기록</a>,
#  <a class="gb4" href="/preferences?hl=ko">설정</a>,
#  <a class="gb4" href="https://accounts.google.com/ServiceLogin?hl=ko&amp;passive=true&amp;continue=https://www.google.com/&amp;ec=GAZAAQ" id="gb_70" target="_top">로그인</a>,
# ...
