# %% [markdown]
# ### 뉴스검색 , 주식검색

# %%
import requests
from pandas import DataFrame
from bs4 import BeautifulSoup
import re
from datetime import datetime
import os

# %%
date = str(datetime.now()) 
date
# Out:
# '2023-02-14 09:54:05.132911'

# %%
date = str(datetime.now())                         #
date = date[:date.rfind(':')].replace(' ', '_')    # 
date = date.replace(':','시') + '분'               # 
print(date)
# Out:
# 2023-02-14_09시54분

# %%
query = input('검색 키워드를 입력하세요 : ')
news_num = int(input('총 필요한 뉴스기사 수를 입력해주세요(숫자만 입력) : '))
query = query.replace(' ', '+')
news_url = 'https://search.naver.com/search.naver?where=news&sm=tab_jum&query={}'
req = requests.get(news_url.format(query))
soup = BeautifulSoup(req.text, 'html.parser') # ----------------- dom객체 
news_dict={}
idx=0
cur_page=1
print()
print('크롤링중.....')
# soup
# while idx < news_num:
table=soup.find('ul',{'class':'list_news'})
print(table)
li_list=table.find_all('li',{'id':re.compile('sp_nws.*')})
li_list
# Out:
# 검색 키워드를 입력하세요 : 튀르키예
# 총 필요한 뉴스기사 수를 입력해주세요(숫자만 입력) : 3
#
# 크롤링중.....
# ...

# %%
area_list=[li.find('div', {'class' : 'news_area'}) for li in li_list]
print(area_list)
# Out:
# [<div class="news_area"> <div class="news_info"> <div class="api_save_group _keep_wrap"> <a aria-pressed="false" class="btn_save _keep_trigger" data-url="https://www.yna.co.kr/view/AKR20230213103200001?input=1195m" href="#" onclick="tCR('a=nws*h.kep&amp;r=1&amp;i=880000D8_000000000000000013753814&amp;u=javascript'); return false;" role="button"><i class="spnew ico_save">문서 저장하기</i></a> <div class="api_ly_save _keep_save_layer"> <a class="spnew_af item item_save _keep_save" data-cr-off="a=nws*h.kepoff&amp;r=1&amp;i=880000D8_000000000000000013753814&amp;u=javascript" data-cr-on="a=nws*h.kepon&amp;r=1&amp;i=880000D8_000000000000000013753814&amp;u=javascript" href="#" role="button">Keep에 저장</a> <a class="spnew_af item item_quick" href="https://keep.naver.com/" onclick="return goOtherCR(this,'a=nws*h.kephome&amp;r=1&amp;i=880000D8_000000000000000013753814&amp;u='+urlencode(this.href));" target="_blank">Keep 바로가기</a> </div></div><div class="info_group"> <a class="info press" href="https://
# ...

# %%
a_list= [area.find('a', {'class' : 'news_tit'}) for area in area_list]
print(a_list)
# Out:
# [<a class="news_tit" href="https://www.yna.co.kr/view/AKR20230213103200001?input=1195m" onclick="return goOtherCR(this, 'a=nws*h.tit&amp;r=1&amp;i=880000D8_000000000000000013753814&amp;g=001.0013753814&amp;u='+urlencode(this.href));" target="_blank" title='[튀르키예 강진] 尹대통령 "구호물품 최대한 확보…재건까지 지원"'>[<mark>튀르키예</mark> 강진] 尹대통령 "구호물품 최대한 확보…재건까지 지원"</a>, <a class="news_tit" href="http://www.newsis.com/view/?id=NISX20230214_0002191750&amp;cID=10301&amp;pID=10300" onclick="return goOtherCR(this, 'a=nws*j.tit&amp;r=6&amp;i=88000127_000000000000000011690325&amp;g=003.0011690325&amp;u='+urlencode(this.href));" target="_blank" title='한 총리 "튀르키예 피해 복구 계속 함께할 것…국민 마음 모아달라"'>한 총리 "<mark>튀르키예</mark> 피해 복구 계속 함께할 것…국민 마음 모아달라"</a>, <a class="news_tit" href="https://www.khan.co.kr/world/world-general/article/202302140735001" onclick="return goOtherCR(this, 'a=nws*h.tit&amp;r=7&amp;i=8800006B_000000000000000003204824&amp;g=032.0003204824&amp;u='+urlencode(this.href));" target="_blank" title="튀르키예·시리아 강진
# ...

# %%
while idx < news_num:
    table=soup.find('ul',{'class':'list_news'})
    li_list=table.find_all('li',{'id':re.compile('sp_nws.*')})
    area_list=[li.find('div', {'class' : 'news_area'}) for li in li_list]
    a_list= [area.find('a', {'class' : 'news_tit'}) for area in area_list]
    
    for n in a_list[:min(len(a_list), news_num-idx)]:
        news_dict[idx] = {'title' : n.get('title'), 'url' : n.get('href')}
        idx+=1
news_dict
# Out:
# {0: {'title': '[튀르키예 강진] 尹대통령 "구호물품 최대한 확보…재건까지 지원"',
#   'url': 'https://www.yna.co.kr/view/AKR20230213103200001?input=1195m'},
#  1: {'title': '한 총리 "튀르키예 피해 복구 계속 함께할 것…국민 마음 모아달라"',
#   'url': 'http://www.newsis.com/view/?id=NISX20230214_0002191750&cID=10301&pID=10300'},
#  2: {'title': '튀르키예·시리아 강진 사망자 3만7000명 넘어',
#   'url': 'https://www.khan.co.kr/world/world-general/article/202302140735001'}}

# %%
date = str(datetime.now())                         #
date = date[:date.rfind(':')].replace(' ', '_')    # 
date = date.replace(':','시') + '분'               # 
print(date)
query = input('검색 키워드를 입력하세요 : ')
news_num = int(input('총 필요한 뉴스기사 수를 입력해주세요(숫자만 입력) : '))
query = query.replace(' ', '+')
news_url = 'https://search.naver.com/search.naver?where=news&sm=tab_jum&query={}'
req = requests.get(news_url.format(query))
soup = BeautifulSoup(req.text, 'html.parser') # ----------------- dom객체 
news_dict = {}
idx = 0
cur_page = 1
print()
print('크롤링중.....')
table = soup.find('ul',{'class':'list_news'})
li_list = table.find_all('li',{'id':re.compile('sp_nws.*')})
area_list = [li.find('div', {'class' : 'news_area'}) for li in li_list]
a_list = [area.find('a', {'class' : 'news_tit'}) for area in area_list]

while idx < news_num:
    table = soup.find('ul',{'class':'list_news'})
    li_list = table.find_all('li',{'id':re.compile('sp_nws.*')})
    area_list = [li.find('div', {'class' : 'news_area'}) for li in li_list]
    a_list = [area.find('a', {'class' : 'news_tit'}) for area in area_list]
    
    for n in a_list[:min(len(a_list), news_num-idx)]:
        news_dict[idx] = {'title' : n.get('title'), 'url' : n.get('href')}
        idx+=1
news_dict
# Out:
# 2023-02-14_10시36분
# 검색 키워드를 입력하세요 : 튀르키예
# 총 필요한 뉴스기사 수를 입력해주세요(숫자만 입력) : 5
#
# 크롤링중.....
# {0: {'title': '[단독] 여야 의원들, 튀르키예 지진 성금에 세비 3% 낸다',
#   'url': 'https://hankookilbo.com/News/Read/A2023021409280003409?did=NA'},
#  1: {'title': '[튀르키예 강진] 尹대통령 "구호물품 최대한 확보…재건까지 지원"',
#   'url': 'https://www.yna.co.kr/view/AKR20230213103200001?input=1195m'},
#  2: {'title': '튀르키예 지진, 7400㎞ 떨어진 우리나라 지하수 수위에도 영향 미쳤다',
#   'url': 'http://www.newsis.com/view/?id=NISX20230214_0002191766&cID=10807&pID=10800'},
#  3: {'title': '튀르키예·시리아 강진 사망자 3만7000명 넘어',
#   'url': 'https://www.khan.co.kr/world/world-general/article/202302140735001'},
#  4: {'title': 'CJ그룹, 튀르키예 강진피해 구호 성금 3억 기부',
#   'url': 'https://www.etnews.com/20230214000026'}}

# %%
date = str(datetime.now())
date = date[:date.rfind(':')].replace(' ', '_')
date = date.replace(':', '시') + '분' 
print(date)

query = input('검색 키워드를 입력하세요 : ')
news_num = int(input('총 필요한 뉴스기사 수를 입력해주세요(숫자만 입력) : '))
query = query.replace(' ', '+')
news_url = 'https://search.naver.com/search.naver?where=news&sm=tab_jum&query={}'
req = requests.get(news_url.format(query))
soup = BeautifulSoup(req.text, 'html.parser') # ---------------------------- dom객체 

news_dict = {}
idx = 0
cur_page = 1
print()

print('크롤링중.....')
table = soup.find('ul', {'class' : 'list_news'})
li_list = table.find_all('li', {'id' : re.compile('sp_nws.*')})
area_list = [li.find('div', {'class' : 'news_area'}) for li in li_list]
a_list = [area.find('a', {'class' : 'news_tit'}) for area in area_list]

while idx < news_num:                        # ----------------------------- 전체 루프 
    table = soup.find('ul', {'class' : 'list_news'})
    li_list = table.find_all('li', {'id' : re.compile('sp_nws.*')})
    area_list = [li.find('div', {'class' : 'news_area'}) for li in li_list]  # ----------- for문 먼저
    a_list = [area.find('a', {'class' : 'news_tit'}) for area in area_list]
    
    for n in a_list[ : min(len(a_list), news_num -idx)]:
        news_dict[idx] = {'title' : n.get('title'), 'url' : n.get('href')}
        idx += 1
    cur_page += 1
    pages = soup.find('div', {'class' : 'sc_page_inner'})
    next_page_url = [p for p in pages.find_all('a') if p.text == str(cur_page)][0].get('href')
    req = requests.get('https://search.naver.com/search.naver' + next_page_url)
    soup = BeautifulSoup(req.text, 'html.parser')
print('크롤링 완료')
print('데이터프레임 변환')
news_df = DataFrame(news_dict).T
news_df
# Out:
# 2023-02-14_12시58분
# 검색 키워드를 입력하세요 : 튀르키예
# 총 필요한 뉴스기사 수를 입력해주세요(숫자만 입력) : 10
#
# 크롤링중.....
# 크롤링 완료
# 데이터프레임 변환
#                                   title  \
# 0       주일 튀르키예 대사관 "일본, 종이학 보내지 말아주세요"
# 1     [단독] 여야 의원들, 튀르키예 지진 성금에 세비 3% 낸다
# 2                 튀르키예 강진이 한반도 지하수까지 영향
# 3  [튀르키예 강진] 尹대통령 "구호물품 최대한 확보…재건까지 지원"
# 4            튀르키예·시리아 강진 사망자 3만7000명 넘어
# 5        정부, 튀르키예 지원 민·관 TF 가동…구호 활동 조율
# 6           성금에 건설장비까지… 튀르키예 지원 팔걷은 기업들
# 7               “튀르키예·시리아 돕자” 재계 온정의 손길
# 8               롯데유통군, 튀르키예 지진 복구 성금 모금
# 9             코리안리, 튀르키예에 10만달러 구호성금 전달
#
#                                                  url
# 0  http://mbn.mk.co.kr/pages/news/newsView.php?ca...
# 1  https://hankookilbo.com/News/Read/A20230214092...
# 2      http://www.fnnews.com/news/202302140934593318
# 3  https://www.yna.co.kr/view/AKR2023021310320000...
# 4  https://www.khan.co.kr/world/world-general/art...
# 5  http://www.newsis.com/view/?id=NISX20230213_00...
# ...

# %%
folder_path = os.getcwd()    # -------------------- 현재 작업경로
print(folder_path)
xlsx_file_name='네이버뉴스_{}_{}.xlsx'.format(query, date)

news_df.to_excel(xlsx_file_name)
print('엑셀 파일 저장 완료 | 경로: {}\\{}'.format(folder_path, xlsx_file_name))
os.startfile(folder_path)
# Out:
# C:\jupyter_home\pythonSource\appSource\crawling
# 엑셀 파일 저장 완료 | 경로: C:\jupyter_home\pythonSource\appSource\crawling\네이버뉴스_튀르키예_2023-02-14_10시49분.xlsx
